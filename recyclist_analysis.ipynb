# %% [markdown]
# # Final Project

# %% [markdown]
# ### Import Dependencies CSV's

# %%
import pandas as pd

# %%
var_serv_df = pd.read_csv("var_service_FINAL_PROJECT.csv")
var_serv_df
# Out:
#       COMPANY  CUST # SERV FIRST NAME           SERV LAST NAME CYCLE ROUTE  \
# 0           1      98             NaN      FAST & EASY MART 56    CA    23
# 1           1      98             NaN      FAST & EASY MART 56    CA    44
# 2           1      98             NaN      FAST & EASY MART 56    CA    44
# 3           1     218             NaN            EHLERS ESTATE    CA    44
# 4           1     218             NaN            EHLERS ESTATE    CA    23
# ...       ...     ...             ...                      ...   ...   ...
# 3684        1   61031            BILL                   SQUIRE    CA    65
# 3685        1   61096             NaN  POPE VALLEY POST OFFICE    CA    21
# 3686        1   61096             NaN  POPE VALLEY POST OFFICE    CA    62
# 3687        1   61706             NaN           P D PROPERTIES    CA    23
# 3688        1   61706             NaN           P D PROPERTIES    CA    61
#
#       DAY  RTE SEQ#  QTY SIZE  ... PHONE #3 TYPE SERVICE COUNTY  \
# 0     THU       250    1   4Y  ...           NaN            NaN
# 1     TUE        60    1   4Y  ...           NaN            NaN
# 2     FRI        50    1   4Y  ...           NaN            NaN
# 3     WED       100    1   4Y  ...           NaN            NaN
# 4     WED       160    1   4Y  ...           NaN            NaN
# ...   ...       ...  ...  ...  ...           ...            ...
# 3684  THU      2610    3   96  ...           NaN            NaN
# 3685  FRI       340    1   CT  ...           NaN            NaN
# 3686  FRI       720    1   96  ...           NaN            NaN
# 3687  THU       180    1   2Y  ...           NaN            NaN
# 3688  THU       100    3   96  ...           NaN            NaN
#
#      SERV MISC FLAG  BILL MISC FLAG   LONGITUDE   LATITUDE MATERIAL  \
# 0               NaN             NaN -122.580120  38.575407      NaN
# 1               NaN             NaN         NaN        NaN      NaN
# 2               NaN             NaN         NaN        NaN      NaN
# 3               NaN             NaN         NaN        NaN      NaN
# 4               NaN             NaN -122.497845  38.531887      NaN
# ...             ...             ...         ...        ...      ...
# 3684            NaN             NaN -122.575385  38.578162      NaN
# 3685            NaN             NaN -122.428386  38.615222      NaN
# 3686            NaN             NaN -122.427635  38.615527      NaN
# 3687            NaN             NaN -122.581514  38.580448      NaN
# 3688            NaN             NaN -122.581514  38.580448      NaN
#
#      START SERVICE DATE END  SERVICE DATE             GENERAL EMAIL
# 0            00/00/0000        00/00/0000                       NaN
# 1            00/00/0000        00/00/0000                       NaN
# 2            00/00/0000        00/00/0000                       NaN
# 3            00/00/0000        00/00/0000  maureen@ehlersestate.com
# 4            00/00/0000        00/00/0000  maureen@ehlersestate.com
# ...                 ...               ...                       ...
# 3684         00/00/0000        00/00/0000                       NaN
# 3685         00/00/0000        00/00/0000                       NaN
# 3686         00/00/0000        00/00/0000                       NaN
# 3687         00/00/0000        00/00/0000                       NaN
# 3688         00/00/0000        00/00/0000                       NaN
#
# [3689 rows x 62 columns]

# %%
var_cust_df = pd.read_csv("var_cust_Final_Project.csv")
var_cust_df
# Out:
#       CO    CUST#              CUSTOMER NAME               SERVICE NAME  \
# 0      1       82         LYNN & CHRIS WEBER         LYNN & CHRIS WEBER
# 1      1       98        FAST & EASY MART 56        FAST & EASY MART 56
# 2      1      218              EHLERS ESTATE              EHLERS ESTATE
# 3      1      345              KELHAM WINERY              KELHAM WINERY
# 4      1      369      NAPA COUNTY FIRE DEPT       RUTHERFORD FIRE DEPT
# ...   ..      ...                        ...                        ...
# 1051   1    60891      ANGWIN VILLAGE CHURCH      ANGWIN VILLAGE CHURCH
# 1052   1    61031                BILL SQUIRE                BILL SQUIRE
# 1053   1    61096    POPE VALLEY POST OFFICE    POPE VALLEY POST OFFICE
# 1054   1    61706             P D PROPERTIES             P D PROPERTIES
# 1055   1  9999999  UPPER VALLEY YARD ACCOUNT  UPPER VALLEY YARD ACCOUNT
#
#      TAX BODY CYCLE    MTH$  BAL DUE  UNAPPLIED  CURRENT  ...  PRICE LIST  \
# 0      S         TA    0.00     0.00        NaN     0.00  ...           S
# 1      C         CA  888.98   963.98        NaN   963.98  ...           C
# 2      SC        CA  965.40   965.40        NaN   965.40  ...          CO
# 3      SC        CA  890.40   980.40        NaN   980.40  ...          CO
# 4      SC        CA   44.86    44.86        NaN    44.86  ...          CO
# ...       ...   ...     ...      ...        ...      ...  ...         ...
# 1051   AC        CA  147.63   147.63        NaN   147.63  ...          CO
# 1052   C         CA  311.79   311.79        NaN   311.79  ...           C
# 1053   PV        CA  174.80   352.22        NaN   177.42  ...          PV
# 1054   CC        CA  482.56   482.56        NaN   482.56  ...          CO
# 1055   S         CM    0.00     0.00        NaN     0.00  ...          CO
#
#       CREDIT LIMIT  AREA CD#3  PHONE #3 SERVICE COUNTY  SERV MISC FLAG  \
# 0              NaN        NaN       NaN            NaN             NaN
# 1              NaN        NaN       NaN            NaN             NaN
# 2              NaN        NaN       NaN            NaN             NaN
# 3              NaN        NaN       NaN            NaN             NaN
# 4              NaN        NaN       NaN            NaN             NaN
# ...            ...        ...       ...            ...             ...
# 1051           NaN        NaN       NaN            NaN             NaN
# 1052           NaN        NaN       NaN            NaN             NaN
# 1053           NaN        NaN       NaN            NaN             NaN
# 1054           NaN        NaN       NaN            NaN             NaN
# 1055           NaN        NaN       NaN            NaN             NaN
#
#      BILL MISC FLAG             GENERAL EMAIL                BILLING EMAIL  \
# 0               NaN                       NaN                          NaN
# 1               NaN                       NaN                          NaN
# 2               NaN  maureen@ehlersestate.com  accounting@ehlersestate.com
# 3               NaN  info@KelhamVineyards.com     info@KelhamVineyards.com
# 4               NaN                       NaN                          NaN
# ...             ...                       ...                          ...
# 1051            NaN                       NaN                          NaN
# 1052            NaN                       NaN                          NaN
# 1053            NaN                       NaN                          NaN
# 1054            NaN                       NaN                          NaN
# 1055            NaN                       NaN                          NaN
#
#      F/C FLAG
# 0           Y
# 1           Y
# 2           Y
# 3           Y
# 4           Y
# ...       ...
# 1051        Y
# 1052        Y
# 1053        Y
# 1054        Y
# 1055        N
#
# [1056 rows x 60 columns]
